# %%
from selenium import webdriver
from time import sleep
# Data manipulation
import pandas as pd
# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC

# %%
driver = webdriver.Chrome(executable_path="C:/Users/Selimhan/AppData/Local/Temp/Rar$EXa13852.31167/chromedriver.exe")


driver.get("https://www.sahibinden.com/kiralik-residence/istanbul")
sleep(4)

#çerezleri kabul etme
driver.find_element("xpath",'//*[@id="onetrust-accept-btn-handler"]')\
    .click()
sleep(3)

#adama tikla

driver.find_element("xpath","/html/body/div[12]/div[2]")\
    .click()
sleep(3)

#sayfada cikan sonuclari 50ye cikar
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="searchResultsSearchForm"]/div/div[3]/div[3]/div[2]/ul/li[2]/a'))))
sleep(3)
    

#ilk linke tikla
driver.find_element("xpath",'//*[@id="searchResultsTable"]/tbody/tr[1]/td[2]/a[1]')\
    .click()
sleep(3)

#//*[@id="searchResultsTable"]/tbody/tr[2]/td[2]/a[1]

#fiyati cek
price = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/h3')
prices_list = []
prices_list.append(price.text)
sleep(3)

#adresi cek
adddress = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/h2')
address_list= []
address_list.append(adddress.text)
sleep(3)

#ilan no cek
ilan_no = driver.find_element("xpath",'//*[@id="classifiedId"]')
ilan_no_list= []
ilan_no_list.append(ilan_no.text)
sleep(3)

#ilan tarihi cek
ilan_tarihi = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[2]/span')
ilan_tarihi_list= []
ilan_tarihi_list.append(ilan_tarihi.text)
sleep(3)

#metrekare brüt cek
metrekare = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[4]/span')
metrekare_list= []
metrekare_list.append(metrekare.text)
sleep(3)


#metrekare net cek
metrekare_net = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[5]/span')
metrekare_net_list= []
metrekare_net_list.append(metrekare_net.text)
sleep(3)


# oda sayisi cek
oda_sayisi = driver.find_element("xpath", '//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[6]/span')
oda_sayisi_list= []
oda_sayisi_list.append(oda_sayisi.text)
sleep(3)

#bina yasi cek
bina_yasi = driver.find_element("xpath", '//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[7]/span')
bina_yasi_list= []
bina_yasi_list.append(bina_yasi.text)
sleep(3)

#kat cek
bulundugu_kat = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[8]/span')
bulundugu_kat_list= []
bulundugu_kat_list.append(bulundugu_kat.text)
sleep(3)

#kac katli oldugunu cek
kac_katli = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[9]/span')
kac_katli_list= []
kac_katli_list.append(kac_katli.text)
sleep(3)




#isitma cek
isitma = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[10]/span')
isitma_list= []
isitma_list.append(isitma.text)
sleep(3)



#banyo sayisi  cek
ban_say = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[11]/span')
ban_say_list= []
ban_say_list.append(ban_say.text)
sleep(3)

#balkon bilgisi  cek
balkon = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[12]/span')
balkon_list= []
balkon_list.append(balkon.text)
sleep(3)




#site adi cek
site_adi = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[16]/span')
site_adi_list= []
site_adi_list.append(site_adi.text)
sleep(3)


#telefon bilgisi cek
tel = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[3]/div[1]/div[5]/dl/div')
tel_list= []
tel_list.append(tel.text)
sleep(3)

driver.back()







#driver.close()
# Out:
# C:\Users\Selimhan\AppData\Local\Temp\ipykernel_13992\1908589649.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="C:/Users/Selimhan/AppData/Local/Temp/Rar$EXa13852.31167/chromedriver.exe")

# %%
from selenium import webdriver
from time import sleep
# Data manipulation
import pandas as pd
# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
from selenium.webdriver.support.ui import WebDriverWait
from selenium.webdriver.common.by import By
from selenium.webdriver.support import expected_conditions as EC



driver = webdriver.Chrome(executable_path="C:/Users/Selimhan/AppData/Local/Temp/Rar$EXa13852.31167/chromedriver.exe")


driver.get("https://www.sahibinden.com/kiralik-residence/istanbul")
sleep(4)

#maximizing the window
driver.maximize_window()

#çerezleri kabul etme
driver.find_element("xpath",'//*[@id="onetrust-accept-btn-handler"]')\
    .click()
sleep(3)

#adama tikla

driver.find_element("xpath","/html/body/div[12]/div[2]")\
    .click()
sleep(3)


#sayfada cikan sonuclari 50ye cikar
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="searchResultsSearchForm"]/div/div[3]/div[3]/div[2]/ul/li[2]/a'))))
sleep(3)
    


def linklere_tikla(link):
    #ilk linke tikla
    driver.find_element("xpath",link)\
    .click()
sleep(13)



prices_list = []
address_list= []
ilan_no_list= []
ilan_tarihi_list= []
metrekare_list= []
metrekare_net_list= []
oda_sayisi_list= []
bina_yasi_list= []
bulundugu_kat_list= []
kac_katli_list= []
isitma_list= []
ban_say_list= []
balkon_list= []
site_adi_list= []


def veri_cek():
        #fiyati cek
        price = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/h3')
        prices_list.append(price.text)
        sleep(13)
        
        #adresi cek
        adddress = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/h2')
        address_list.append(adddress.text)
        sleep(13)

        #ilan no cek
        ilan_no = driver.find_element("xpath",'//*[@id="classifiedId"]')
        ilan_no_list.append(ilan_no.text)
        sleep(13)

        #ilan tarihi cek
        ilan_tarihi = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[2]/span')
        ilan_tarihi_list.append(ilan_tarihi.text)
        sleep(13)

        #metrekare brüt cek
        metrekare = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[4]/span')
        metrekare_list.append(metrekare.text)
        sleep(13)


        #metrekare net cek
        metrekare_net = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[5]/span')
        metrekare_net_list.append(metrekare_net.text)
        sleep(13)


        # oda sayisi cek
        oda_sayisi = driver.find_element("xpath", '//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[6]/span')
        oda_sayisi_list.append(oda_sayisi.text)
        sleep(13)

        #bina yasi cek
        bina_yasi = driver.find_element("xpath", '//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[7]/span')
        bina_yasi_list.append(bina_yasi.text)
        sleep(13)

        #kat cek
        bulundugu_kat = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[8]/span')
        bulundugu_kat_list.append(bulundugu_kat.text)
        sleep(13)

        #kac katli oldugunu cek
        kac_katli = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[9]/span')
        kac_katli_list.append(kac_katli.text)
        sleep(13)


        #isitma cek
        isitma = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[10]/span')
        isitma_list.append(isitma.text)
        sleep(13)


        #banyo sayisi  cek
        ban_say = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[11]/span')
        ban_say_list.append(ban_say.text)
        sleep(13)

        #balkon bilgisi  cek
        balkon = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[12]/span')
        balkon_list.append(balkon.text)
        sleep(13)


        #site adi cek
        site_adi = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[16]/span')
        site_adi_list.append(site_adi.text)
        sleep(13)


linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[1]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[2]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[4]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[5]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[6]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[7]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[8]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[9]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[10]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[11]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[12]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[13]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[14]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[15]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[16]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[17]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[18]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[19]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[20]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[21]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[22]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[23]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[24]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[25]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[26]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[27]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[28]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[29]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[30]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[31]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[32]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[33]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[34]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[35]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[36]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[37]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[38]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[39]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[40]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[41]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[42]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[43]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[44]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[45]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[46]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[47]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[48]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[49]/td[2]/a[1]')
veri_cek()
driver.back()
linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[50]/td[2]/a[1]')
veri_cek()
driver.back()









driver.close()

print([ilan_no_list, ilan_tarihi_list, metrekare_list, metrekare_net_list, address_list, prices_list, oda_sayisi_list, 
      bina_yasi_list, isitma_list, ban_say_list, balkon_list, site_adi_list])
# Out:
# C:\Users\Selimhan\AppData\Local\Temp\ipykernel_13992\643968230.py:14: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="C:/Users/Selimhan/AppData/Local/Temp/Rar$EXa13852.31167/chromedriver.exe")
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [20], in <cell line: 148>()
#     146 veri_cek()
#     147 driver.back()
# --> 148 linklere_tikla('//*[@id="searchResultsTable"]/tbody/tr[4]/td[2]/a[1]')
#     149 veri_cek()
#     150 driver.back()
#
# Input In [20], in linklere_tikla(link)
#      41 def linklere_tikla(link):
#      42     #ilk linke tikla
# ---> 43     driver.find_element("xpath",link)\
#      44     .click()
#
# File D:\Programs\Anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py:861, in WebDriver.find_element(self, by, value)
# ...

# %%
print([ilan_no_list, ilan_tarihi_list, metrekare_list, metrekare_net_list, address_list, prices_list, oda_sayisi_list, 
      bina_yasi_list,isitma_list, ban_say_list, balkon_list, site_adi_list])
# Out:
# [['1063582877', '989295570', '1063515668', '962230765', '1030977654'], ['19 Kasım 2022', '19 Kasım 2022', '19 Kasım 2022', '19 Kasım 2022', '19 Kasım 2022'], ['190', '137', '180', '440', '300'], ['180', '106', '138', '380', '240'], ['İstanbul / Sarıyer / Ayazağa Mh.', 'İstanbul / Beşiktaş / Levazım Mh.', 'İstanbul / Sarıyer / Ayazağa Mh.', 'İstanbul / Beşiktaş / Levazım Mh.', 'İstanbul / Sarıyer / Pınar Mh.'], ['38.000 TL', '60.000 TL', '47.000 TL', '185.000 TL', '145.000 TL'], ['3+1', '2+1', '3+1', '4+1', '4+1'], ['5-10 arası', '5-10 arası', '3', '11-15 arası', '11-15 arası'], ['Merkezi (Pay Ölçer)', 'VRV', 'Merkezi (Pay Ölçer)', 'Merkezi (Pay Ölçer)', 'Doğalgaz (Kombi)'], ['1', '2', '2', '3', '4'], ['Var', 'Yok', 'Var', 'Var', 'Var'], ['Belirtilmemiş', 'Belirtilmemiş', 'Avangart İstanbul', 'Bellevue Residences', 'İstinye Park Residence']]

# %%
driver = webdriver.Chrome(executable_path="C:/Users/Selimhan/AppData/Local/Temp/Rar$EXa13852.31167/chromedriver.exe")


driver.get("https://www.sahibinden.com/kiralik-residence/istanbul")
sleep(4)

#çerezleri kabul etme
driver.find_element("xpath",'//*[@id="onetrust-accept-btn-handler"]')\
    .click()
sleep(3)

#adama tikla

driver.find_element("xpath","/html/body/div[12]/div[2]")\
    .click()
sleep(3)


#sayfada cikan sonuclari 50ye cikar
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="searchResultsSearchForm"]/div/div[3]/div[3]/div[2]/ul/li[2]/a'))))
sleep(3)



#ilk linke tikla
links= driver.find_element("xpath",'//*[@id="searchResultsTable"]/tbody/tr[*]/td[2]/a[1]')\
    .click()
sleep(3)

print(links)
# Out:
# C:\Users\Selimhan\AppData\Local\Temp\ipykernel_13992\4159387241.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="C:/Users/Selimhan/AppData/Local/Temp/Rar$EXa13852.31167/chromedriver.exe")
# None

# %% [markdown]
# ## ikinci deneme

# %%
driver = webdriver.Chrome(executable_path="C:/Users/Selimhan/AppData/Local/Temp/Rar$EXa13852.31167/chromedriver.exe")


driver.get("https://www.sahibinden.com/kiralik-residence/istanbul")
sleep(4)


driver.find_element("xpath", '//*[@id="searchResultsSearchForm"]/div/div[3]/div[3]/p').text
# Out:
# C:\Users\Selimhan\AppData\Local\Temp\ipykernel_23296\1168830964.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="C:/Users/Selimhan/AppData/Local/Temp/Rar$EXa13852.31167/chromedriver.exe")
# ---------------------------------------------------------------------------
# NoSuchWindowException                     Traceback (most recent call last)
# Input In [29], in <cell line: 8>()
#       4 driver.get("https://www.sahibinden.com/kiralik-residence/istanbul")
#       5 sleep(4)
# ----> 8 driver.find_element("xpath", '//*[@id="searchResultsSearchForm"]/div/div[3]/div[3]/p').text
#
# File D:\Programs\Anaconda\lib\site-packages\selenium\webdriver\remote\webdriver.py:861, in WebDriver.find_element(self, by, value)
#     858     by = By.CSS_SELECTOR
#     859     value = '[name="%s"]' % value
# --> 861 return self.execute(Command.FIND_ELEMENT, {"using": by, "value": value})["value"]
#
# ...

# %%
driver = webdriver.Chrome(executable_path="C:/Users/Selimhan/AppData/Local/Temp/Rar$EXa13852.31167/chromedriver.exe")


driver.get("https://www.sahibinden.com/kiralik-residence/istanbul")
sleep(4)


kac_sayfa_var= driver.find_element("xpath", '//*[@id="searchResultsSearchForm"]/div/div[3]/div[3]/p').text




for sayfa_linki in range(1,):

    #çerezleri kabul etme
    driver.find_element("xpath",'//*[@id="onetrust-accept-btn-handler"]')\
        .click()
    sleep(3)

    #adama tikla

    driver.find_element("xpath","/html/body/div[12]/div[2]")\
        .click()
    sleep(3)

    #sayfada cikan sonuclari 50ye cikar
    driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="searchResultsSearchForm"]/div/div[3]/div[3]/div[2]/ul/li[2]/a'))))
    sleep(3)





    #ilk linke tikla
    driver.find_element("xpath",'//*[@id="searchResultsTable"]/tbody/tr[sayfa_linki]/td[2]/a[1]')\
        .click()
    sleep(3)

    #//*[@id="searchResultsTable"]/tbody/tr[2]/td[2]/a[1]

    #fiyati cek
    price = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/h3')
    prices_list = []
    prices_list.append(price.text)


    #adresi cek
    adddress = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/h2')
    address_list= []
    address_list.append(adddress.text)


    #ilan no cek
    ilan_no = driver.find_element("xpath",'//*[@id="classifiedId"]')
    ilan_no_list= []
    ilan_no_list.append(ilan_no.text)


    #ilan tarihi cek
    ilan_tarihi = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[2]/span')
    ilan_tarihi_list= []
    ilan_tarihi_list.append(ilan_tarihi.text)


    #metrekare brüt cek
    metrekare = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[4]/span')
    metrekare_list= []
    metrekare_list.append(metrekare.text)



    #metrekare net cek
    metrekare_net = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[5]/span')
    metrekare_net_list= []
    metrekare_net_list.append(metrekare_net.text)



    # oda sayisi cek
    oda_sayisi = driver.find_element("xpath", '//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[6]/span')
    oda_sayisi_list= []
    oda_sayisi_list.append(oda_sayisi.text)


    #bina yasi cek
    bina_yasi = driver.find_element("xpath", '//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[7]/span')
    bina_yasi_list= []
    bina_yasi_list.append(bina_yasi.text)


    #kat cek
    bulundugu_kat = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[8]/span')
    bulundugu_kat_list= []
    bulundugu_kat_list.append(bulundugu_kat.text)


    #kac katli oldugunu cek
    kac_katli = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[9]/span')
    kac_katli_list= []
    kac_katli_list.append(kac_katli.text)





    #isitma cek
    isitma = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[10]/span')
    isitma_list= []
    isitma_list.append(isitma.text)




    #banyo sayisi  cek
    ban_say = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[11]/span')
    ban_say_list= []
    ban_say_list.append(ban_say.text)


    #balkon bilgisi  cek
    balkon = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[12]/span')
    balkon_list= []
    balkon_list.append(balkon.text)





    #site adi cek
    site_adi = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[2]/ul/li[16]/span')
    site_adi_list= []
    site_adi_list.append(site_adi.text)



    #telefon bilgisi cek
    tel = driver.find_element("xpath",'//*[@id="classifiedDetail"]/div/div[2]/div[3]/div[1]/div[5]/dl/div[2]/dd')
    tel_list= []
    tel_list.append(tel.text)










#driver.close()
# Out:
# C:\Users\Selimhan\AppData\Local\Temp\ipykernel_23296\3492390838.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="C:/Users/Selimhan/AppData/Local/Temp/Rar$EXa13852.31167/chromedriver.exe")
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# Input In [26], in <cell line: 8>()
#       4 driver.get("https://www.sahibinden.com/kiralik-residence/istanbul")
#       5 sleep(4)
# ----> 8 kac_sayfa_var= driver.find_element("xpath", '//*[@id="searchResultsSearchForm"]/div/div[3]/div[3]/p').text
#      13 for sayfa_linki in range(1,):
#      14
#      15     #çerezleri kabul etme
#      16     driver.find_element("xpath",'//*[@id="onetrust-accept-btn-handler"]')\
#      17         .click()
#
# ...

# %%
driver = webdriver.Chrome(executable_path="C:/Users/Selimhan/AppData/Local/Temp/Rar$EXa13852.31167/chromedriver.exe")


driver.get("https://www.sahibinden.com/kiralik-residence/istanbul")
sleep(4)

#çerezleri kabul etme
driver.find_element("xpath",'//*[@id="onetrust-accept-btn-handler"]')\
    .click()
sleep(3)

#adama tikla

driver.find_element("xpath","/html/body/div[12]/div[2]")\
    .click()
sleep(3)

#sayfada cikan sonuclari 50ye cikar
driver.execute_script("arguments[0].click();", WebDriverWait(driver, 20).until(EC.element_to_be_clickable((By.XPATH, '//*[@id="searchResultsSearchForm"]/div/div[3]/div[3]/div[2]/ul/li[2]/a'))))
sleep(3)
    

#ilk linke tikla
driver.find_element("xpath",'//*[@id="searchResultsTable"]/tbody/tr[*]/td[2]/a[1]')\
    .click()
sleep(3)
# Out:
# C:\Users\Selimhan\AppData\Local\Temp\ipykernel_23296\3683945904.py:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(executable_path="C:/Users/Selimhan/AppData/Local/Temp/Rar$EXa13852.31167/chromedriver.exe")

# %%
print([ilan_no_list, ilan_tarihi_list, metrekare_list, metrekare_net_list, address_list, prices_list, oda_sayisi_list, 
      bina_yasi_list, kat_list, isitma_list, ban_say_list, balkon_list, site_adi_list, tel_list])
# Out:
# [['1063230119'], ['17 Kasım 2022'], ['200'], ['160'], ['İstanbul / Sarıyer / Maslak Mah.'], ['49.000 TL'], ['3+1'], ['4'], ['7'], ['Merkezi (Pay Ölçer)'], ['2'], ['Var'], ['Ağaoğlu Maslak 1453'], ['0 (533) 612 52 15']]

# %%
print(ilan_no_list)
# Out:
# ['1063230119']

# %%
print(ilan_tarihi_list)
# Out:
# ['17 Kasım 2022']

# %%
print(metrekare_list)
# Out:
# ['200']

# %%
print(metrekare_net_list)
# Out:
# ['160']

# %%
print(address_list)
# Out:
# ['İstanbul / Sarıyer / Maslak Mah.']

# %%
print(prices_list)
# Out:
# ['49.000 TL']

# %%
    
item_titles = driver.find_elements_by_xpath('//*[@id="searchResultsTable"]/tbody/tr[*]/td[2]')
item_prices = driver.find_elements_by_xpath('//*[@id="searchResultsTable"]/tbody/tr[*]/td[3]')
item_loca = driver.find_elements_by_xpath('//*[@id="searchResultsTable"]/tbody/tr[*]/td[5]')
item_date = driver.find_elements_by_xpath('//*[@id="searchResultsTable"]/tbody/tr[*]/td[4]')


# boş liste
titles_list = []
prices_list = []
loca_list = []
date_list = []

# Loop over the item_titles and item_prices
for title in item_titles:
    titles_list.append(title.text)
for prices in item_prices:
    prices_list.append(prices.text)
for locat in item_loca:
    loca_list.append(locat.text)
for dat in item_date:
    date_list.append(dat.text)




print(titles_list)
print(prices_list)
print(loca_list)
print(date_list)

driver.close()
